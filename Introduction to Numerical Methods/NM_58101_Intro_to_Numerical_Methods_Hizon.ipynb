# %% [markdown]
# <a href="https://colab.research.google.com/github/TiffanyHizon/58101_Numerical_Methods/blob/main/Introduction%20to%20Numerical%20Methods/NM_58101_Intro_to_Numerical_Methods_Hizon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction to Numerical Methods

# %%
b = 'Sally'
b = int(4)
b = 'John'
b
# Out:
# 'John'

# %%
b = 'Sally'
#b = int(4)
type(b)
b
# Out:
# 'Sally'

# %%
x = 'enjoying'
print('Python programming is ', x)
# Out:
# Python programming is  enjoying

# %%
x = 'enjoying'
y = 'Python programming is '
z = y + x
z
# Out:
# 'Python programming is enjoying'

# %%
a, b, c = 0, -1, 5
c%=2
c
# Out:
# 1

# %%
x = 3
y = 5
compare = x > y
compare
# Out:
# False

# %%
x = 3
y = 5
x > x and y > y
# Out:
# False
