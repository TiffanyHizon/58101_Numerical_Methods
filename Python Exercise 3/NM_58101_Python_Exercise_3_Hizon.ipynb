# %% [markdown]
# <a href="https://colab.research.google.com/github/TiffanyHizon/58101_Numerical_Methods/blob/main/Python%20Exercise%203/NM_58101_Python_Exercise_3_Hizon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Determinants of Matrix

# %%
import numpy as np

# %%
A = np.array([
              [1, 2, -1], 
              [4, 6, -2],
              [-1, 3, 3]
            ])

A
# Out:
# array([[ 1,  2, -1],
#        [ 4,  6, -2],
#        [-1,  3,  3]])

# %%
print(round((np.linalg.det(A))))
# Out:
# -14
