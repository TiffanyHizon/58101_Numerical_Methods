# %% [markdown]
# <a href="https://colab.research.google.com/github/TiffanyHizon/58101_Numerical_Methods/blob/main/Prelim%20Exam/Prelim_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Prelim Exam
#
# $$\begin{bmatrix} 1&2&3\\2&3&3\\3&4&-2 \\\end{bmatrix}\\ $$

# %%
import numpy as np

# %%
A = np.array([
              [1, 2, 3],
              [2, 3, 3],
              [3, 4, -2]
            ])

# %%
A_Det = round(np.linalg.det(A))
A_Det
# Out:
# 5
